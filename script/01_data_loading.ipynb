# %%
import sys
sys.path.append('notebooks/src')
from Data_Loader import load_raw

sales, channels, products, customers, delivery = load_raw()
print("✅ All files loaded!")
# Out:
# c:\Users\Hello\Downloads\project\BoatSalesProject\PythonProject\notebooks/src\Data_Loader.py:7: DtypeWarning: Columns (0: FestivalName) have mixed types. Specify dtype option on import or set low_memory=False.
#   sales     = pd.read_csv(f"{RAW}\\Sales_data.csv")           # exact name
# ✅ All files loaded!

# %%
# Quick inspection
for name, df in {'Sales': sales, 'Channels': channels,
                 'Products': products, 'Customers': customers,
                 'Delivery': delivery}.items():
    print(f"\n=== {name} ===")
    print(f"Shape: {df.shape}")
    print(df.dtypes)
    print(df.isnull().sum())
# Out:
# === Sales ===
# Shape: (975000, 32)
# SalesID                 int64
# OrderDate                 str
# OrderHour               int64
# CustomerID              int64
# ProductID               int64
# ChannelID               int64
# DeliveryPartnerID       int64
# Quantity                int64
# GrossMRPValue           int64
# DiscountPct           float64
# DiscountAmount        float64
# SellingPrice          float64
# NetSales              float64
# GSTRate                 int64
# GSTAmount             float64
# COGS                  float64
# ShippingCost          float64
# Profit                float64
# PaymentMethod             str
# OrderStatus               str
# CancellationReason        str
# ReturnReason              str
# DeliveryDays            int64
# CustomerTier              str
# CustomerSegment           str
# CityTier                  str
# ChannelType               str
# IsFestivalPeriod        int64
# FestivalName              str
# IsWeekend               int64
# ProductCategory           str
# HeroFlag                int64
# dtype: object
# SalesID                    0
# OrderDate                  0
# OrderHour                  0
# CustomerID                 0
# ProductID                  0
# ChannelID                  0
# DeliveryPartnerID          0
# Quantity                   0
# GrossMRPValue              0
# DiscountPct                0
# DiscountAmount             0
# SellingPrice               0
# NetSales                   0
# GSTRate                    0
# GSTAmount                  0
# COGS                       0
# ShippingCost               0
# Profit                     0
# PaymentMethod              0
# OrderStatus                0
# CancellationReason    959215
# ReturnReason          929605
# DeliveryDays               0
# CustomerTier               0
# CustomerSegment            0
# CityTier                   0
# ChannelType                0
# IsFestivalPeriod           0
# FestivalName          558942
# IsWeekend                  0
# ProductCategory            0
# HeroFlag                   0
# dtype: int64
#
# === Channels ===
# Shape: (7, 6)
# ChannelID         int64
# ChannelName         str
# ChannelType         str
# ChannelScope        str
# RegionScope         str
# BaseShare       float64
# dtype: object
# ChannelID       0
# ChannelName     0
# ChannelType     0
# ChannelScope    0
# RegionScope     0
# BaseShare       0
# dtype: int64
#
# === Products ===
# Shape: (106, 11)
# ProductID             int64
# Brand                   str
# Category                str
# SubCategory             str
# ProductName             str
# HeroFlag              int64
# LaunchYear            int64
# MRP                 float64
# CostPrice           float64
# PopularityWeight    float64
# DemandCluster           str
# dtype: object
# ProductID           0
# Brand               0
# Category            0
# SubCategory         0
# ProductName         0
# HeroFlag            0
# LaunchYear          0
# MRP                 0
# CostPrice           0
# PopularityWeight    0
# DemandCluster       0
# dtype: int64
#
# === Customers ===
# Shape: (150000, 11)
# CustomerID            int64
# SignupDate              str
# Gender                  str
# AgeBand                 str
# Segment                 str
# Tier                    str
# City                    str
# State                   str
# Region                  str
# PreferredChannel        str
# ActivityWeight      float64
# dtype: object
# CustomerID          0
# SignupDate          0
# Gender              0
# AgeBand             0
# Segment             0
# Tier                0
# City                0
# State               0
# Region              0
# PreferredChannel    0
# ActivityWeight      0
# dtype: int64
#
# === Delivery ===
# Shape: (180, 7)
# DeliveryPartnerID      int64
# PartnerName              str
# HomeCity                 str
# Region                   str
# VehicleType              str
# Rating               float64
# ExperienceYears        int64
# dtype: object
# DeliveryPartnerID    0
# PartnerName          0
# HomeCity             0
# Region               0
# VehicleType          0
# Rating               0
# ExperienceYears      0
# dtype: int64
